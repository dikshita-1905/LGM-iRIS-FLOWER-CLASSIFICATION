# %% [markdown]
# Name:Dikshita N Padte
#
# # Iris Flower Classification ML Project
#
#  LGMVIP-AUG-21
#
#  Data Science and Bussiness Analytics Internship

# %% [markdown]
# ****************************************************************************************************************************************************************

# %% [markdown]
# Importing the dataset

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("/content/drive/MyDrive/Iris.csv")
df
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      1            5.1  ...           0.2     Iris-setosa
# 1      2            4.9  ...           0.2     Iris-setosa
# 2      3            4.7  ...           0.2     Iris-setosa
# 3      4            4.6  ...           0.2     Iris-setosa
# 4      5            5.0  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# Data cleaning and data preprocessing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df=df.drop("Id",axis=1)
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
df['Species'].value_counts()
#n = len(df[df['Species'] == 'versicolor'])
#print("No of Versicolor in Dataset:",n)
#n1 = len(iris[iris['Species'] == 'virginica'])
#print("No of Virginica in Dataset:",n1)

#n2 = len(iris[iris['Species'] == 'setosa'])
#print("No of Setosa in Dataset:",n2)
# Out:
# Iris-virginica     50
# Iris-setosa        50
# Iris-versicolor    50
# Name: Species, dtype: int64

# %%
df.isnull()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            False         False          False         False    False
# 1            False         False          False         False    False
# 2            False         False          False         False    False
# 3            False         False          False         False    False
# 4            False         False          False         False    False
# ..             ...           ...            ...           ...      ...
# 145          False         False          False         False    False
# 146          False         False          False         False    False
# 147          False         False          False         False    False
# 148          False         False          False         False    False
# 149          False         False          False         False    False
#
# [150 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
#   Histogram

# %%
sns.distplot(df.SepalLengthCm,hist=True,kde=True,bins=10,hist_kws=dict(edgecolor='k',color="Green",linewidth=1)) #y-axis represents the counts and x-axis represents value
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **************************************************
# *****************************************************

# %%
sns.distplot(df.SepalWidthCm,kde=True,hist=True,bins=10,hist_kws=dict(edgecolor="k",linewidth=2),color='Red')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df.PetalLengthCm,kde=True,hist=True,bins=10,hist_kws=dict(edgecolor="k",linewidth=2),color='Violet')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df.PetalWidthCm,kde=True,hist=True,bins=10,hist_kws=dict(edgecolor="k",linewidth=2),color='Yellow')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df['SepalLengthCm'].hist()  #y-axis represents the counts and x-axis represents value

# %%
df['PetalLengthCm'].hist()

# %%
df['SepalWidthCm'].hist()

# %%
df['PetalWidthCm'].hist()

# %% [markdown]
# Pie Chart

# %%
 fig = plt.figure()
ax = fig.add_axes([0,0,2,2])  #size
ax.axis('off')
l = ['Versicolor', 'Setosa', 'Virginica']
s = [50,50,50]
ax.pie(s, labels = l,autopct='%1.6f%%')   #6 deciml places
plt.show()

# %% [markdown]
# ## KDE PLOTS

# %%
sns.kdeplot(df['PetalLengthCm'],shade=True,color='Green',bw="silverman")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using silverman for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %%
sns.kdeplot(df['PetalWidthCm'],shade=True,color='Maroon',bw="silverman")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using silverman for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %%
sns.kdeplot(df['SepalLengthCm'],shade=True,color='Pink',bw="silverman")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using silverman for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %%
sns.kdeplot(df['SepalWidthCm'],shade=True,color='Cyan',bw="silverman")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using silverman for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %%
sns.kdeplot(df['PetalLengthCm'],df['PetalWidthCm'],shade=True,color='red',cbar=True,cmap='Accent',n_levels=10)  #cmap and n_levels
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.kdeplot(df['SepalLengthCm'],df['SepalWidthCm'],shade=True,color='red',cbar=True,cmap='coolwarm',n_levels=10)  #cmap and n_levels
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Scatter Plot

# %%
plt.scatter(x="PetalLengthCm",y="PetalWidthCm",data=df,color='Maroon')
plt.scatter(x="SepalLengthCm",y="SepalWidthCm",data=df,color='Green')   #DESMOS

# %% [markdown]
# Joint Plot

# %%
sns.jointplot(x="PetalLengthCm",y="PetalWidthCm",data=df,color='Violet')

# %%
sns.jointplot(x="SepalLengthCm",y="SepalWidthCm",data=df.loc[(df['SepalWidthCm']>0)&(df['SepalWidthCm']<10),:],kind="hex",size=6,color="Yellow")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2073: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Bar Plot

# %%
fig = plt.figure(figsize=(15,9)) 

ax1 = fig.add_subplot(1,2,1)  # (height,width,number of plot)
sns.barplot(df.Species,df.SepalLengthCm, palette='copper')
plt.xticks(rotation=90)
ax1 = fig.add_subplot(1,2,2)
sns.barplot(df.Species,df.SepalWidthCm)
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
#  ***************************************************************************************************************************************************************

# %%
fig = plt.figure(figsize=(15,9)) 

ax1 = fig.add_subplot(1,2,1)  # (height,width,number of plot)
sns.barplot(df.Species,df.PetalLengthCm, palette='copper')
plt.xticks(rotation=90)
ax1 = fig.add_subplot(1,2,2)
sns.barplot(df.Species,df.PetalWidthCm)
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.bar(df['Species'],df['SepalLengthCm'],width=0.4,align="edge",label="SepalLengthCm")
plt.bar(df['Species'],df['SepalWidthCm'],width=-0.4,align="edge",label="SepalWidthCm")
plt.legend()
plt.show()

# %%
plt.bar(df['Species'],df['PetalLengthCm'],width=0.4,align="edge",label="PetalLengthCm")
plt.bar(df['Species'],df['PetalWidthCm'],width=-0.4,align="edge",label="PetalWidthCm")
plt.legend()
plt.show()

# %%
sns.countplot(x='Species',data=df)

# %% [markdown]
# Density Plot

# %%
df.plot(kind ='density',subplots = True, layout =(3,3),sharex = False)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3306f98750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3306f6a310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3306f1e990>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f3306f55fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3306e98710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3306eced90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f3306e904d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3306e43c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3306e43c90>]],
#       dtype=object)

# %% [markdown]
# Box Plot

# %%
df.plot(kind ='box',subplots = True, layout =(2,5),sharex = False)
# Out:
# SepalLengthCm       AxesSubplot(0.125,0.536818;0.133621x0.343182)
# SepalWidthCm     AxesSubplot(0.285345,0.536818;0.133621x0.343182)
# PetalLengthCm     AxesSubplot(0.44569,0.536818;0.133621x0.343182)
# PetalWidthCm     AxesSubplot(0.606034,0.536818;0.133621x0.343182)
# dtype: object

# %% [markdown]
# Violin Plot

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)   #(row,col,index)
sns.violinplot(x='Species',y='PetalLengthCm',data=df)
plt.subplot(2,2,2)
sns.violinplot(x='Species',y='PetalWidthCm',data=df)
plt.subplot(2,2,3)
sns.violinplot(x='Species',y='SepalLengthCm',data=df)
plt.subplot(2,2,4)
sns.violinplot(x='Species',y='SepalWidthCm',data=df)

# %% [markdown]
# Pair Plot

# %%
sns.pairplot(df,hue='Species');

# %% [markdown]
# Heat Map

# %%
#Heat Maps
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.heatmap(df.corr(),annot=True,cmap='Oranges_r',linewidths=3,linecolor='k',square=True,mask=False, vmin=-1, vmax=1,cbar_kws={"orientation": "horizontal"},cbar=True)

# %% [markdown]
# # Let's dive into the Machine Learning Algorithms

# %%
x=df.drop("Species",axis=1)
x
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
y=df["Species"]
y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=30)

# %% [markdown]
# # **KNN CLASSIFICATION**

# %%
from sklearn.neighbors import KNeighborsClassifier                   #Importing KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(x_train,y_train)                                            #Fitting the data
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
knn.score(x_test,y_test)                                          #Calculating the accuracy of the model on testing data
# Out:
# 0.9210526315789473

# %%
data=pd.read_csv("/content/drive/MyDrive/Iris_predict.csv")          #Importing the data to be predicted
data
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            6.5           2.1            3.5           0.6
# 1            3.5           1.5            4.6           1.2
# 2            2.4           2.1            2.8           2.1
# 3            5.5           3.0            1.9           1.9
# 4            3.6           3.1            2.5           3.1
# 5            2.9           2.9            2.9           0.7
# 6            7.1           1.8            5.0           1.1

# %%
knn.predict(data)                                                  #Prediction on the new data
# Out:
# array(['Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor'],
#       dtype=object)

# %% [markdown]
# # `Decision Tree`

# %%
from sklearn.tree import DecisionTreeClassifier                              #Importing DecisionTreeClassifier

# %%
model=DecisionTreeClassifier()

# %%
model.fit(x_train,y_train)                                    #Fitting on the data
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
model.score(x_test,y_test)                          #Calculating the accuracy of the model on training data
# Out:
# 0.9473684210526315

# %%
data=pd.read_csv('/content/drive/MyDrive/Iris_predict.csv')          #Importing the data to be predicted
data
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            6.5           2.1            3.5           0.6
# 1            3.5           1.5            4.6           1.2
# 2            2.4           2.1            2.8           2.1
# 3            5.5           3.0            1.9           1.9
# 4            3.6           3.1            2.5           3.1
# 5            2.9           2.9            2.9           0.7
# 6            7.1           1.8            5.0           1.1

# %%
model.predict(data)                                                  #Prediction on the new data
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica'], dtype=object)

# %% [markdown]
# # Thank You
